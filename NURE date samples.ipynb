# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
# %matplotlib inline

# %%
data=pd.read_csv(r'M:\critical\nure.csv', parse_dates=[['sampdat','time']], index_col='sampdat_time')
# Out:
# C:\Users\jesse.pisel\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (19,20,28,29,31,35,46,47,48,66,68,79,145) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#                    rec_no prime_id  replc  samptyp  rec_cnt  latitude  \
# sampdat_time
# 1978-06-22 13:00  5013606   M39081    0.0       12        1   45.0028
# 1978-06-22 14:00  5013607   M39082    0.0       12        1   45.0025
# 1978-07-05 16:00  5013669   M39160    0.0       12        1   45.0014
# 1978-07-05 16:00  5013670   M39161    0.0       11        1   45.0019
# 1978-07-10 17:00  5013687   M39181    0.0       12        1   45.0008
#
#                   longitude doelab  laslid  ornlid   ...     zn_ppm  zr_ppm  \
# sampdat_time                                         ...
# 1978-06-22 13:00  -109.5150   LASL  M39081     NaN   ...      110.0     NaN
# 1978-06-22 14:00  -109.4792   LASL  M39082     NaN   ...      103.0     NaN
# 1978-07-05 16:00  -109.2808   LASL  M39160     NaN   ...      -47.0     NaN
# 1978-07-05 16:00  -109.2781   LASL  M39161     NaN   ...       50.0     NaN
# 1978-07-10 17:00  -109.9964   LASL  M39181     NaN   ...       49.0     NaN
#
# ...

# %%
plt.scatter(data['longitude'], data['latitude'])

# %%
data['count']=1
data.index = pd.to_datetime(data.index, errors='coerce')
dayofweek = data.index.dayofweek

# %%
applieds=data['count'].resample('h').sum()

# %%
plt.scatter(data.iloc[0:500,6],data.iloc[0:500,5], c=data.index[0:500], cmap='viridis')
plt.colorbar()

# %%
from IPython import display

for i in range(1,len(d2),100):
    plt.clf()
    #plt.scatter(d2['longitude'][0:i],d2['latitude'][0:i], c=range(i))
    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.set_extent([-103, -112, 40, 46])
    ax.add_image(stamen_terrain, 6)
    #plt.scatter(d2['longitude'][0:50],d2['latitude'][0:50], c=range(50), cmap='viridis',transform=ccrs.Geodetic())
    plt.scatter(d2['longitude'][0:i],d2['latitude'][0:i], c=range(i),s=2)
    plt.xlim(-111.5,-103.5)
    plt.ylim(40.75,45.25)
    plt.title(d2.index[i])
    
    #plt.figure(figsize=(10,10))
    #display.display(plt.gcf())
    display.clear_output(wait=True)
    time.sleep(0.001)
    plt.savefig('M:/exploration/'+str(i)+'.jpg')

# %%
plt.scatter(data.loc[data['sampdat_time'] == data.time.unique()[0]]['lon'],data.loc[data['time'] == df.time.unique()[i]]['lat'])

# %%
d2data.index[0:5+5]
# Out:
# DatetimeIndex(['1978-06-22 13:00:00', '1978-06-22 14:00:00',
#                '1978-07-05 16:00:00', '1978-07-05 16:00:00',
#                '1978-07-10 17:00:00', '1978-07-10 18:00:00',
#                '1978-07-17 13:00:00', '1978-07-17 17:00:00',
#                '1978-07-17 17:00:00', '1978-07-17 19:00:00'],
#               dtype='datetime64[ns]', name='sampdat_time', freq=None)

# %%
plt.scatter(d2['longitude'][0:50],d2['latitude'][0:50], c=range(50), cmap='viridis')

# %%
d2=data.sort_index()

# %%
d2['longitude'].index
# Out:
# DatetimeIndex(['1976-03-27 14:00:00', '1976-03-27 15:00:00',
#                '1976-03-27 19:00:00', '1976-03-28 10:00:00',
#                '1976-03-28 11:00:00', '1976-03-28 11:00:00',
#                '1976-03-28 12:00:00', '1976-03-28 12:00:00',
#                '1976-03-28 12:00:00', '1976-03-28 13:00:00',
#                ...
#                                'NaT',                 'NaT',
#                                'NaT',                 'NaT',
#                                'NaT',                 'NaT',
#                                'NaT',                 'NaT',
#                                'NaT',                 'NaT'],
#               dtype='datetime64[ns]', name='sampdat_time', length=18527, freq=None)

# %%
plt.plot(data.index[0:100])

# %%
import geoplot as gplt
import geopandas as gpd

# %%
import cartopy.crs as ccrs
import cartopy.io.img_tiles as cimgt

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-103, -112, 40, 46])
ax.add_image(stamen_terrain, 6)
plt.scatter(d2['longitude'][0:50],d2['latitude'][0:50], c=range(50), cmap='viridis',transform=ccrs.Geodetic())
